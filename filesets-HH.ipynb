# %%
import os
import json
import subprocess, sys

# %%
with open('pmap.json', 'r') as f:
    pmap = json.load(f)

# %%
for year in ['2016APV','2016','2017','2018']:

    with open('infiles-nano/datasets_'+year+'.json', 'r') as f:
        datasets = json.load(f)

    for k, val in pmap.items():

        # one infile per pmap key
        outfilename = 'infiles-nano/'+year+'_'+k+'.json'

        if 'HHTo4B' not in k:
            continue

        filesets = {}
        for v in val:

            filesets[v] = []
            for d in datasets[v]:
                longstring = os.popen("dasgoclient --query=\"file dataset="+d+"\"").read()
                files_no_redirector = longstring.split('\n')
                filesets[v] += ["root://cmsxrootd.fnal.gov//store/test/xrootd/T1_US_FNAL" + f for f in files_no_redirector if len(f) > 0]

            print(v, len(filesets[v]))
           
        with open(outfilename, 'w') as outfile:
            json.dump(filesets, outfile)
# Out:
# QCD_PT300to470 48
# QCD_PT470to600 47
# QCD_PT600to800 84
# QCD_PT800to1000 35
# QCD_PT1000to1400 30
# QCD_PT1400to1800 24
# QCD_PT1800to2400 13
# QCD_PT2400to3200 18
# QCD_PT3200toInf 5
# TTTo2L2Nu 49
# TTToHadronic 146
# TTToSemiLeptonic 138
# TT_MTT700To1000 88
# TT_MTT1000ToInf 43
# ST_t-channel_antitop 35
# ST_t-channel_top 86
# ST_tW_antitop 23
# ST_tW_top 24
# WJetsToQQ_HT400to600 26
# WJetsToQQ_HT600to800 52
# WJetsToQQ_HT800toInf 32
# WJetsToLNu_HT200to400 60
# WJetsToLNu_HT400to600 11
# WJetsToLNu_HT600to800 13
# WJetsToLNu_HT800to1200 46
# WJetsToLNu_HT1200to2500 3
# WJetsToLNu_HT2500toInf 17
# ZJetsToQQ_HT400to600 23
# ZJetsToQQ_HT600to800 29
# ZJetsToQQ_HT800toInf 40
# DYJetsToLL_HT200to400 26
# DYJetsToLL_HT400to600 32
# DYJetsToLL_HT600to800 7
# DYJetsToLL_HT800to1200 36
# DYJetsToLL_HT1200to2500 19
# DYJetsToLL_HT2500toInf 22
# WW 41
# ZZ 17
# WZ 16
# EWKZ_ZToQQ 22
# EWKZ_ZToLL 10
# EWKZ_ZToNuNu 28
# EWKWminus_WToQQ 19
# EWKWplus_WToQQ 25
# EWKWminus_WToLNu 18
# EWKWplus_WToLNu 8
# GluGluHToBB 5
# VBFHToBB 10
# WminusH_HToBB_WToQQ 33
# WplusH_HToBB_WToQQ 26
# WminusH_HToBB_WToLNu 31
# WplusH_HToBB_WToLNu 41
# ZH_HToBB_ZToQQ 39
# ZH_HToBB_ZToLL 21
# ZH_HToBB_ZToNuNu 28
# ggZH_HToBB_ZToQQ 58
# ggZH_HToBB_ZToLL 26
# ggZH_HToBB_ZToNuNu 20
# ttHToBB 26
# JetHT_Run2016F 5
# JetHT_Run2016G 70
# JetHT_Run2016H 72
# SingleMuon_Run2016F 5
# SingleMuon_Run2016G 70
# SingleMuon_Run2016H 82
