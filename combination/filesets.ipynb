# %%
import os
import json
import subprocess, sys

# %%
with open('pmap.json', 'r') as f:
    pmap = json.load(f)

# %%
for year in ['2016APV','2016','2017','2018']:

    with open('infiles-nano/datasets_'+year+'.json', 'r') as f:
        datasets = json.load(f)

    for k, val in pmap.items():

        # one infile per pmap key
        outfilename = 'infiles-nano/'+year+'_'+k+'.json'

        filesets = {}
        for v in val:

            if 'data' in k:
                if year == '2016APV' and not ('2016' in v and 'HIPM' in v):
                    continue
                if year != "2016APV" and year not in v:
                    continue
                if year == "2016" and "HIPM" in v:
                    continue

            filesets[v] = []
            for d in datasets[v]:
                longstring = os.popen("dasgoclient --query=\"file dataset="+d+"\"").read()
                files_no_redirector = longstring.split('\n')
                filesets[v] += ["root://cmsxrootd.fnal.gov//store/test/xrootd/T1_US_FNAL" + f for f in files_no_redirector if len(f) > 0]

            print(v, len(filesets[v]))
           
        with open(outfilename, 'w') as outfile:
            json.dump(filesets, outfile)
# Out:
# GluGluHToBB 9
# VBFHToBB 56
# WminusH_HToBB_WToQQ 34
# WplusH_HToBB_WToQQ 24
# WminusH_HToBB_WToLNu 19
# WplusH_HToBB_WToLNu 23
# ZH_HToBB_ZToQQ 45
# ggZH_HToBB_ZToQQ 25
# ZH_HToBB_ZToLL 35
# ggZH_HToBB_ZToLL 21
# ZH_HToBB_ZToNuNu 24
# ggZH_HToBB_ZToNuNu 20
# ttHToBB 25
# GluGluHToBB 5
# VBFHToBB 10
# WminusH_HToBB_WToQQ 33
# WplusH_HToBB_WToQQ 26
# WminusH_HToBB_WToLNu 31
# WplusH_HToBB_WToLNu 41
# ZH_HToBB_ZToQQ 39
# ggZH_HToBB_ZToQQ 58
# ZH_HToBB_ZToLL 21
# ggZH_HToBB_ZToLL 26
# ZH_HToBB_ZToNuNu 28
# ggZH_HToBB_ZToNuNu 20
# ttHToBB 26
# GluGluHToBB 12
# VBFHToBB 19
# WminusH_HToBB_WToQQ 31
# WplusH_HToBB_WToQQ 14
# WminusH_HToBB_WToLNu 30
# WplusH_HToBB_WToLNu 22
# ZH_HToBB_ZToQQ 76
# ggZH_HToBB_ZToQQ 27
# ZH_HToBB_ZToLL 45
# ggZH_HToBB_ZToLL 38
# ZH_HToBB_ZToNuNu 27
# ggZH_HToBB_ZToNuNu 23
# ttHToBB 46
# GluGluHToBB 14
# VBFHToBB 28
# WminusH_HToBB_WToQQ 32
# WplusH_HToBB_WToQQ 22
# WminusH_HToBB_WToLNu 46
# WplusH_HToBB_WToLNu 37
# ZH_HToBB_ZToQQ 34
# ggZH_HToBB_ZToQQ 24
# ZH_HToBB_ZToLL 26
# ggZH_HToBB_ZToLL 32
# ZH_HToBB_ZToNuNu 36
# ggZH_HToBB_ZToNuNu 35
# ttHToBB 57
