# %%
import os, sys
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
pmap = {}

pmap['ggF'] = ['GluGluHToBB']

pmap['VBF'] = ['VBFHToBB']

pmap['WH_HToQQ'] = ['WminusH_HToBB_WToQQ',
                    'WplusH_HToBB_WToQQ']
pmap['WH_HToLNu'] = ['WminusH_HToBB_WToLNu',
                     'WplusH_HToBB_WToLNu']

pmap['ZH_HtoQQ'] = ['ZH_HToBB_ZToQQ',
                    'ggZH_HToBB_ZToQQ']

pmap['ZH_HToLL'] = ['ZH_HToBB_ZToLL',
                    'ggZH_HToBB_ZToLL']

pmap['ZH_HToNuNu'] = ['ZH_HToBB_ZToNuNu',
                      'ggZH_HToBB_ZToNuNu']
    
pmap['ttH'] = ['ttHToBB']

with open('pmap.json', 'w') as outfile:
    json.dump(pmap, outfile, indent=4)
