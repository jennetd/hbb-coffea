# %%
import pandas as pd
import numpy as np

from plotter import *

# %%
df16 = pd.read_csv('2016/systematics.csv',index_col=0).reset_index(drop=True)
df17 = pd.read_csv('2017/systematics.csv',index_col=0).reset_index(drop=True)
df18 = pd.read_csv('2018/systematics.csv',index_col=0).reset_index(drop=True)

# %%
s="DDB"
plot_systs_sig_bybin(s,df16,df17,df18)
plot_systs_bkg_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:174: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:209: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="L1Prefiring"
plot_systs_sig_bybin(s,df16,df17,df18)
plot_systs_bkg_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:174: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:209: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="JES"
plot_systs_sig_bybin(s,df16,df17,df18)
plot_systs_bkg_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:174: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:209: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="JER"
plot_systs_sig_bybin(s,df16,df17,df18)
plot_systs_bkg_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:174: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:209: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="UES"
plot_systs_sig_bybin(s,df16,df17,df18)
plot_systs_bkg_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:174: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:209: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="jet_trigger"
plot_systs_sig_bybin(s,df16,df17,df18)
plot_systs_bkg_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:174: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:209: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="pileup_weight"
plot_systs_sig_bybin(s,df16,df17,df18)
plot_systs_bkg_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:174: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:209: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="btagWeight"
plot_systs_sig_bybin(s,df16,df17,df18)
plot_systs_bkg_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:174: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:209: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="PDF"
plot_systs_sig_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="scale"
plot_systs_sig_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="ISR"
plot_systs_sig_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="FSR"
plot_systs_sig_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:78: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d1K_NLO"
plot_systs_vjets_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:280: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:316: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d2K_NLO"
plot_systs_vjets_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:280: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:316: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d3K_NLO"
plot_systs_vjets_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:280: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:316: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d1kappa_EW"
plot_systs_vjets_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:280: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:316: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d2kappa_EW"
plot_systs_vjets_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:280: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:316: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d3kappa_EW"
plot_systs_vjets_bybin(s,df16,df17,df18)
# Out:
# /srv/plotter.py:280: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/plotter.py:316: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
