# %%
import os, subprocess
import json
import uproot3
import awkward as ak
import numpy as np
from coffea import processor, util, hist
import pickle

from plotter import *

import matplotlib
matplotlib.rcParams.update({'font.size': 18})

import warnings
warnings.filterwarnings('ignore')

# %%
year = '2016APV'
ddbthr = 0.64

# %%
with open('lumi.json') as f:
  lumi = json.load(f)

with open('xsec.json') as f:
  xs = json.load(f)

with open('pmap.json') as f:
  pmap = json.load(f)

systematics = ['nominal',
               'jet_triggerUp','jet_triggerDown',
               'btagSFbc_'+year+'Up','btagSFbc_'+year+'Down','btagSFlight_'+year+'Up','btagSFlight_'+year+'Down',
               'UESUp','UESDown','JESUp','JESDown','JERUp','JERDown',
               'pileup_weightUp','pileup_weightDown',
               'muon_ID_'+year+'_valueDown','muon_ID_'+year+'_valueDown',
               'muon_ISO_'+year+'_valueDown','muon_ISO_'+year+'_valueDown',
               'muon_TRIGNOISO_'+year+'_valueDown','muon_TRIGNOISO_'+year+'_valueDown',
               'L1PrefiningUp','L1PrefiringDown',
              ]

# %%
ggf = pickle.load(open(str(year)+'/templates.pkl','rb')).integrate('region','signal-ggf').integrate('mjj',overflow='allnan')
vbf = pickle.load(open(str(year)+'/templates.pkl','rb')).integrate('region','signal-vbf').integrate('mjj',overflow='allnan')
mucr = pickle.load(open(str(year)+'/templates.pkl','rb')).integrate('region','muoncontrol').integrate('mjj',overflow='allnan')

# %%
ggf.identifiers('systematic')
# Out:
# [<StringBin (JERDown) instance at 0x7f3d555cbb50>,
#  <StringBin (JERUp) instance at 0x7f3dc8396130>,
#  <StringBin (JESDown) instance at 0x7f3da81712b0>,
#  <StringBin (JESUp) instance at 0x7f3da8171190>,
#  <StringBin (L1PrefiringDown) instance at 0x7f3da8171b50>,
#  <StringBin (L1PrefiringUp) instance at 0x7f3da81719a0>,
#  <StringBin (PDF_weightDown) instance at 0x7f3d555c0bb0>,
#  <StringBin (PDF_weightUp) instance at 0x7f3d5552cdf0>,
#  <StringBin (PDFaS_weightDown) instance at 0x7f3d5552cb50>,
#  <StringBin (PDFaS_weightUp) instance at 0x7f3da808d610>,
#  <StringBin (UEPS_FSRDown) instance at 0x7f3d5552cb80>,
#  <StringBin (UEPS_FSRUp) instance at 0x7f3d555c07c0>,
#  <StringBin (UEPS_ISRDown) instance at 0x7f3dc83bf370>,
#  <StringBin (UEPS_ISRUp) instance at 0x7f3d555cb580>,
#  <StringBin (UESDown) instance at 0x7f3d555db790>,
#  <StringBin (UESUp) instance at 0x7f3d555e7be0>,
#  <StringBin (W_d2kappa_EWDown) instance at 0x7f3dc83cffa0>,
#  <StringBin (W_d2kappa_EWUp) instance at 0x7f3dc83cfa60>,
#  <StringBin (W_d3kappa_EWDown) instance at 0x7f3dc83cf7c0>,
#  <StringBin (W_d3kappa_EWUp) instance at 0x7f3dc83cf790>,
#  <StringBin (Z_d2kappa_EWDown) instance at 0x7f3dc83cfee0>,
#  <StringBin (Z_d2kappa_EWUp) instance at 0x7f3dc83cfc70>,
#  <StringBin (Z_d3kappa_EWDown) instance at 0x7f3dc83cf6a0>,
#  <StringBin (Z_d3kappa_EWUp) instance at 0x7f3dc83cf160>,
#  <StringBin (aS_weightDown) instance at 0x7f3da80d5880>,
#  <StringBin (aS_weightUp) instance at 0x7f3d5552c9a0>,
#  <StringBin (btagSFbc_2016APVDown) instance at 0x7f3da81710a0>,
#  <StringBin (btagSFbc_2016APVUp) instance at 0x7f3da8171460>,
#  <StringBin (btagSFbc_correlatedDown) instance at 0x7f3da8171c70>,
#  <StringBin (btagSFbc_correlatedUp) instance at 0x7f3da81711c0>,
#  <StringBin (btagSFlight_2016APVDown) instance at 0x7f3da8171af0>,
#  <StringBin (btagSFlight_2016APVUp) instance at 0x7f3da8171400>,
#  <StringBin (btagSFlight_correlatedDown) instance at 0x7f3da81713a0>,
#  <StringBin (btagSFlight_correlatedUp) instance at 0x7f3da81716d0>,
#  <StringBin (d1K_NLODown) instance at 0x7f3dc83cfe50>,
#  <StringBin (d1K_NLOUp) instance at 0x7f3dc83cfdf0>,
#  <StringBin (d1kappa_EWDown) instance at 0x7f3dc83cf0d0>,
#  <StringBin (d1kappa_EWUp) instance at 0x7f3dc83cfb80>,
#  <StringBin (d2K_NLODown) instance at 0x7f3dc83cfac0>,
#  <StringBin (d2K_NLOUp) instance at 0x7f3dc83cfa90>,
#  <StringBin (d3K_NLODown) instance at 0x7f3dc83cfa30>,
#  <StringBin (d3K_NLOUp) instance at 0x7f3dc83cf8e0>,
#  <StringBin (jet_triggerDown) instance at 0x7f3da8171910>,
#  <StringBin (jet_triggerUp) instance at 0x7f3da8171520>,
#  <StringBin (muon_ID_2016preVFP_valueDown) instance at 0x7f3da81717c0>,
#  <StringBin (muon_ID_2016preVFP_valueUp) instance at 0x7f3da8171340>,
#  <StringBin (muon_ISO_2016preVFP_valueDown) instance at 0x7f3da8171640>,
#  <StringBin (muon_ISO_2016preVFP_valueUp) instance at 0x7f3da8171730>,
#  <StringBin (muon_TRIGNOISO_2016preVFP_valueDown) instance at 0x7f3da8171040>,
#  <StringBin (muon_TRIGNOISO_2016preVFP_valueUp) instance at 0x7f3da8171580>,
#  <StringBin (nominal) instance at 0x7f3da8171430>,
#  <StringBin (pileup_weightDown) instance at 0x7f3da8171b20>,
#  <StringBin (pileup_weightUp) instance at 0x7f3da8171130>,
#  <StringBin (scalevar_3ptDown) instance at 0x7f3da808da00>,
#  <StringBin (scalevar_3ptUp) instance at 0x7f3d5552cc10>,
#  <StringBin (scalevar_7ptDown) instance at 0x7f3dc83bf0d0>,
#  <StringBin (scalevar_7ptUp) instance at 0x7f3d5552cd90>]

# %%
ggf_pass = ggf.sum('pt1').integrate('ddb1',int_range=slice(ddbthr,1))
vbf_pass = vbf.sum('pt1').integrate('ddb1',int_range=slice(ddbthr,1))
mucr_pass = mucr.sum('pt1').integrate('ddb1',int_range=slice(ddbthr,1))

ggf_all = ggf.sum('ddb1','pt1')
vbf_all = vbf.sum('ddb1','pt1')
mucr_all = mucr.sum('ddb1','pt1')

# %%
s = 'JES'
plot_syst_allbkg(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/bkg_'+s)
plot_syst_allbkg(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/bkg_'+s+'_pass')

plot_syst_allsig(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/sig_'+s)
plot_syst_allsig(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/sig_'+s+'_pass')

# %%
s = 'JER'
plot_syst_allbkg(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/bkg_'+s)
plot_syst_allbkg(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/bkg_'+s+'_pass')

plot_syst_allsig(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/sig_'+s)
plot_syst_allsig(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/sig_'+s+'_pass')

# %%
s = 'UES'
plot_syst_allbkg(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/bkg_'+s)
plot_syst_allbkg(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/bkg_'+s+'_pass')

plot_syst_allsig(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/sig_'+s)
plot_syst_allsig(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/sig_'+s+'_pass')

# %%
s = 'btagSFbc_'+year
plot_syst_allbkg(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/bkg_'+s)
plot_syst_allbkg(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/bkg_'+s+'_pass')

plot_syst_allsig(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/sig_'+s)
plot_syst_allsig(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/sig_'+s+'_pass')

# %%
s = 'btagSFlight_'+year
plot_syst_allbkg(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/bkg_'+s)
plot_syst_allbkg(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/bkg_'+s+'_pass')

plot_syst_allsig(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/sig_'+s)
plot_syst_allsig(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/sig_'+s+'_pass')

# %%
s = 'jet_trigger'
plot_syst_allbkg(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/bkg_'+s)
plot_syst_allbkg(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/bkg_'+s+'_pass')

plot_syst_allsig(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/sig_'+s)
plot_syst_allsig(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/sig_'+s+'_pass')

# %%
s = 'pileup_weight'
plot_syst_allbkg(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/bkg_'+s)
plot_syst_allbkg(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/bkg_'+s+'_pass')

plot_syst_allsig(ggf_all, vbf_all, s, '$m_{sd}$ [GeV]', year+' '+s, year+'/sig_'+s)
plot_syst_allsig(ggf_pass, vbf_pass, s, '$m_{sd}$ [GeV]', year+' '+s+' DDB pass', year+'/sig_'+s+'_pass')

# %%
s = 'muon_TRIGNOISO_'+year+'_value'
if year == '2016APV':
    s = 'muon_TRIGNOISO_2016preVFP_value'
elif year == '2016':
    s = 'muon_TRIGNOISO_2016postVFP_value'

plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/mucr_'+s+'_pass')
# Out:
# muon_TRIGNOISO_2016preVFP_value

# %%
s = 'muon_ISO_'+year+'_value'
if year == '2016APV':
    s = 'muon_ISO_2016preVFP_value'
elif year == '2016':
    s = 'muon_ISO_2016postVFP_value'
    
plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/mucr_'+s+'_pass')

# %%
s = 'muon_ID_'+year+'_value'
if year == '2016APV':
    s = 'muon_ID_2016preVFP_value'
elif year == '2016':
    s = 'muon_ID_2016postVFP_value'
    
plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/mucr_'+s+'_pass')

# %%
s = 'JES'
plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/bkg_mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/bkg_mucr_'+s+'_pass')

# %%
s = 'JER'
plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/bkg_mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/bkg_mucr_'+s+'_pass')

# %%
s = 'UES'
plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/bkg_mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/bkg_mucr_'+s+'_pass')

# %%
s = 'btagSFlight_'+year
plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/bkg_mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/bkg_mucr_'+s+'_pass')

# %%
s = 'btagSFbc_'+year
plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/bkg_mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/bkg_mucr_'+s+'_pass')

# %%
s = 'pileup_weight'
plot_syst_mucr(mucr_all, s, '$m_{sd}$ [GeV]', year+' muonsyst', year+'/bkg_mucr_'+s)
plot_syst_mucr(mucr_pass, s,'$m_{sd}$ [GeV]', year+' muonsyst DDB pass', year+'/bkg_mucr_'+s+'_pass')
