# %%
import pandas as pd
import numpy as np

from plotter import *
# Out:
# /opt/conda/lib/python3.8/site-packages/coffea/util.py:154: FutureWarning: In coffea version v2023.3.0 (target date: 31 Mar 2023), this will be an error.
# (Set coffea.deprecations_as_errors = True to get a stack trace now.)
# ImportError: coffea.hist is deprecated
#   warnings.warn(message, FutureWarning)

# %%
df16apv = pd.read_csv('../fits-combine8/hbb-unblind-ewkz/2016APV/systematics.csv',index_col=0).reset_index(drop=True)
df16 = pd.read_csv('../fits-combine8/hbb-unblind-ewkz/2016/systematics.csv',index_col=0).reset_index(drop=True)
df17 = pd.read_csv('../fits-combine8/hbb-unblind-ewkz/2017/systematics.csv',index_col=0).reset_index(drop=True)
df18 = pd.read_csv('../fits-combine8/hbb-unblind-ewkz/2018/systematics.csv',index_col=0).reset_index(drop=True)

# %%
s="DDB"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="L1Prefiring"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="JES"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="JER"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="UES"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="jet_trigger"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="pileup_weight"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="btagSFlight"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="btagSFbc"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
plot_systs_bkg_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:179: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:215: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="PDF"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="scale"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="ISR"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="FSR"
plot_systs_sig_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:81: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:117: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d1K_NLO"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:324: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d2K_NLO"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:324: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d3K_NLO"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:324: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d1kappa_EW"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:324: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d2kappa_EW"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:324: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)

# %%
s="d3kappa_EW"
plot_systs_vjets_bybin(s,df16apv,df16,df17,df18)
# Out:
# /srv/notebooks/plotter.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
# /srv/notebooks/plotter.py:324: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(thebins)
